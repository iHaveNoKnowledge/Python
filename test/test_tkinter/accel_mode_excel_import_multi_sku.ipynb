# %%
import pandas as pd

# สมมุติว่า DataFrame ของคุณมีข้อมูลดังนี้
file_path = r"Accel_mode_test.xlsx"
# data = {
#     'Orders': [1, 2, 3],
#     'Co1SN': ['A123', 'B456', 'C789'],
#     'Co2SN': ['X111', 'Y222', 'Z333']
# }
# df = pd.DataFrame(data)
df = pd.read_excel(file_path)
print(df)

# ดึงชื่อคอลัมน์ทั้งหมด
columns = df.columns.tolist()
print(columns)

# # เก็บข้อมูลในแต่ละคอลัมน์ลงในตัวแปรแยกกัน
variables = {col: df[col].tolist() for col in columns}

print(variables)

# # แสดงผลลัพธ์
# for col, values in variables.items():
#     print(f"{col}:")
#     print(values)
#     print()
# Out:
#            orders  cp        sn PR5-000001 PR5-000002
# 0             NaN NaN  69asdasd   aaaaaaaa    vbbbbbb
# 1             NaN NaN       NaN        NaN        NaN
# 2  24040507U2YC02 NaN       NaN        NaN        NaN
# 3  2404050DD47BV5 NaN       NaN        NaN        NaN
# 4  2404050QVUBDSH NaN       NaN        NaN        NaN
# ['orders', 'cp', 'sn', 'PR5-000001', 'PR5-000002']
# {'orders': [nan, nan, '24040507U2YC02', '2404050DD47BV5', '2404050QVUBDSH'], 'cp': [nan, nan, nan, nan, nan], 'sn': ['69asdasd', nan, nan, nan, nan], 'PR5-000001': ['aaaaaaaa', nan, nan, nan, nan], 'PR5-000002': ['vbbbbbb', nan, nan, nan, nan]}
