# %%
from tkinter import *
from tkinter import messagebox
# %run autopageMKII_test.ipynb
# %run test_input_receiver.ipynb
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 3
#       1 from tkinter import *
#       2 from tkinter import messagebox
# ----> 3 get_ipython().run_line_magic('run', 'autopageMKII_test.ipynb')
#       4 # %run test_input_receiver.ipynb
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\interactiveshell.py:2504, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2502     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2503 with self.builtin_trap:
# -> 2504     result = fn(*args, **kwargs)
#    2506 # The code below prevents the output from being displayed
#    2507 # when using magics with decorator @output_can_be_silenced
#    2508 # when the last Python token in the expression is a ';'.
#    2509 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\magics\execution.py:749, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     747     with preserve_keys(self.shell.user_ns, '__file__'):
#     748         self.shell.user_ns['__file__'] = filename
# --> 749         self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#     750     return
#     752 # Control the response to exit() calls made by the script being run
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\interactiveshell.py:2992, in InteractiveShell.safe_execfile_ipy(self, fname, shell_futures, raise_exceptions)
#    2990 with prepended_to_syspath(dname):
#    2991     try:
# -> 2992         for cell in get_cells():
#    2993             result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#    2994             if raise_exceptions:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\interactiveshell.py:2980, in InteractiveShell.safe_execfile_ipy.<locals>.get_cells()
#    2978 """generator for sequence of code blocks to run"""
#    2979 if fname.suffix == ".ipynb":
# -> 2980     from nbformat import read
#    2981     nb = read(fname, as_version=4)
#    2982     if not nb.cells:
#
# ModuleNotFoundError: No module named 'nbformat'

# %%
window1 = Tk()
window1.title("Autosamatic")
# Out:
# ''

# %% [markdown]
# ---

# %% [markdown]
# # CUSTOM WINDOWS

# %% [markdown]
# > Window1

# %%
window1.geometry("800x600")
window1.configure(bg="#444")

# %% [markdown]
# >> Window1 sub1 Choose Source

# %% [markdown]
# ---

# %% [markdown]
# # FUNCTIONS

# %%
def search():
    search_query = entered_order.get()  
    print("search() ทำงานและได้ผลลัพธ์: ",search_query)
    entered_order.set("")
    report_log.config(state=NORMAL)
    report_log.insert(END, search_query + "\n")
    report_log.config(state=DISABLED)
    order_receive(search_query)

# %%
# Subwindow Close
def on_subwindow_close(sub_window):
    sub_window.destroy()

# %% [markdown]
# ---

# %% [markdown]
# # FRAMES

# %% [markdown]
# > Frame1

# %%
entry_frame = Frame(window1, padx=5, pady=5, bg="#444")
entry_frame.pack()

# %% [markdown]
# > Frame2

# %%
log_frame = Frame(window1, bg="#444")
log_frame.pack(side='bottom', pady=(0,30))

# %% [markdown]
# ---

# %% [markdown]
# # **WIDGETS**

# %% [markdown]
# > Labels

# %%
inp1_label_order = Label(entry_frame, text="Order: ", bg="#FFF", width=10)
inp1_label_order.grid(row=0,column=0, padx=5)

# %% [markdown]
# > Inputs

# %%
entered_order = StringVar()
inp1_order_input = Entry(entry_frame, textvariable=entered_order, width=50)

inp1_order_input.grid(row=0,column=2)

# %% [markdown]
# > Buttons

# %%
inp1_search_btn = Button(entry_frame, text="ค้นหา", bg="#747474", command=search, width=10)
inp1_search_btn.grid(row=0,column=4, padx=5)

# %% [markdown]
# > Log windows

# %%
report_log = Text(log_frame, state=DISABLED)
scrollbar= Scrollbar(log_frame, command=report_log.yview)
scrollbar.pack(side="right", fill="y") 
scrollbar.config()
report_log.pack(side='bottom', fill=X)
report_log.config(yscrollcommand=scrollbar.set)

# %% [markdown]
# > Subwindow

# %%
window1_sub1 = Toplevel(window1)
window1_sub1.transient(window1)
window1_sub1.geometry("300x200")
window1_sub1.title("Data Source")
window1_sub1_label = Label(window1_sub1, text="")



##*  function
def on_close():
    window1_sub1.destroy()
window1_sub1.protocol("WM_DELETE_WINDOW", on_close)

def select_api():
    global result
    result = "API"
    print("Select API")
    window1_sub1.destroy()
window1_sub1.protocol("WM_DELETE_WINDOW", on_close)
    

def select_excel():
    global result
    result = "Excel"
    print("Select Excel")
    window1_sub1.destroy()
window1_sub1.protocol("WM_DELETE_WINDOW", on_close)
    


##* btn
sub1_btn1 = Button(window1_sub1, text="API", command=select_api).pack()
sub1_btn2 = Button(window1_sub1, text="Excel", command=select_excel).pack()


window1_sub1.wait_window()
print("รอปิด")
print("Result: ", result)
if (result == "API"):
    print("เลือก API")
    report_log.config(state=NORMAL)
    report_log.insert(END, "ยังไม่พร้อมใช้งานแค่ทำปุ่มรอไว้เฉยๆ" + "\n")
    report_log.config(state=DISABLED)
elif (result == "Excel"):
    print("เลือก Excel")
    report_log.config(state=NORMAL)
    report_log.insert(END, "ใช้ Excel " + "\n")
    report_log.config(state=DISABLED)




##* optional
# result_sub = messagebox.askyesno("vcvcv", )
# Out:
# รอปิด
# Result:  Excel
# เลือก Excel

# %% [markdown]
# ---

# %% [markdown]
# # **RUN GUI**

# %% [markdown]
# > Check DataFrame

# %%
get_data_frame()
# Out:
# มี Data Frame

# %% [markdown]
# > Launch Gui

# %%
window1.mainloop()

# %%
def piramidInwza2(n):
    lvs = n
    display = ""
    for lv in range(lvs):
        display = " "*(n-lv)
        display = display+("*"*lv)+"*"+("*"*lv)
        print(display)

piramidInwza2(5)
# Out:
#      *
#     ***
#    *****
#   *******
#  *********
